# %%
73 ^ 87
# Out:
# 30

# %%
x = 0b1001001 ^ 0b1010111
print(x)
# Out:
# 30

# %%
bin(x)
# Out:
# '0b11110'

# %%
# ?bin
# Out:
# Signature: bin(number, /)
# Docstring:
# Return the binary representation of an integer.
#
# >>> bin(2796202)
# '0b1010101010101010101010'
# Type:      builtin_function_or_method

# %%
# See https://stackoverflow.com/a/699892 for guidance on zero padding.
format(x, '07b')
# Out:
# '0011110'
